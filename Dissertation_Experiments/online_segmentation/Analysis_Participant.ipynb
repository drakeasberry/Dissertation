# %%
import pandas as pd
import segFunctions

# %%
# runs the csv_from_excel function:
# creates csv for segmentation experiment lists
#segFunctions.csv_from_excel('./data/original_data/part_files/part111_inglés_A_Segmentation.csv','part111_inglés_A_Segmentation','./data/temp_data/part_files/part111_inglés_A_Segmentation.csv')
df = pd.read_csv('./data/original_data/part_files/part111_inglés_A_Segmentation.csv')

# %%
df.head()
# Out:
#    Order        Word     Translation  corrAnsEspV practiceListA  \
# 0    0.0     pladeno              NW          0.0           NaN
# 1    0.0   delantera  first position          1.0           NaN
# 2    0.0  garbardina        raincoat          1.0           NaN
# 3    1.0       terzo              NW          0.0           NaN
# 4    2.0   pellizcar           pinch          1.0           NaN
#
#   practiceListA0 practiceListA1 practiceListA2 practiceListA3 practiceListA4  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#       ...      06_Sexo (Gender): 07_País de nacimiento (Birth country):  \
# ...

# %%
headerlist = list(df.columns.values)
len(headerlist)
# Out:
# 157

# %%
df2 = pd.DataFrame(headerlist)

# %%
df2
# Out:
#                                                      0
# 0                                                Order
# 1                                                 Word
# 2                                          Translation
# 3                                          corrAnsEspV
# 4                                        practiceListA
# 5                                       practiceListA0
# 6                                       practiceListA1
# 7                                       practiceListA2
# 8                                       practiceListA3
# 9                                       practiceListA4
# 10                                      practiceListA5
# 11                                      practiceListA6
# 12                                      practiceListA7
# 13                                          conditionA
# 14                                       stimuliListA0
# 15                                       stimuliListA1
# ...

# %%
df_columnindexing = pd.DataFrame(list(df.columns.values))

# %%
df3
# Out:
#                                                      0
# 0                                                Order
# 1                                                 Word
# 2                                          Translation
# 3                                          corrAnsEspV
# 4                                        practiceListA
# 5                                       practiceListA0
# 6                                       practiceListA1
# 7                                       practiceListA2
# 8                                       practiceListA3
# 9                                       practiceListA4
# 10                                      practiceListA5
# 11                                      practiceListA6
# 12                                      practiceListA7
# 13                                          conditionA
# 14                                       stimuliListA0
# 15                                       stimuliListA1
# ...
