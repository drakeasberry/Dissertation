prof.thisIndex,trials_blp_att.thisRepN,trials_blp_att.thisTrialN,trials_blp_att.thisN,trials_blp_att.thisIndex,lexEsp_key_resp.keys,lexEsp_key_resp.corr,lexEsp_key_resp.rt,seg_key_resp.keys,seg_key_resp.rt,expSyl_key_resp.keys,expSyl_key_resp.corr,expSyl_key_resp.rt,lexEng_key_resp.keys,lexEng_key_resp.corr,lexEng_key_resp.rt,rating_lang_hist.response,rating_lang_hist.rt,rating_lang_hist_2.response,rating_lang_hist_2.rt,rating_lang_hist_3.response,rating_lang_hist_3.rt,rating_blp_use.response,rating_blp_use.rt,rating_lang_prof.response,rating_lang_prof.rt,rating_lang_att.response,rating_lang_att.rt,01_Participante (Participant):,02_Sesión (Session):,03_Nombre (First name):,04_Apellido (Last name):,05_Edad (Age):,06_Sexo (Gender):,07_País de nacimiento (Birth country):,08_Lugar de residencia (Place of residence):,09_Nivel más alto de formación académica (Highest level of formal education):,10_Idioma preferido (Preferred language):,date,expName,psychopyVersion,frameRate,blah'
header_names = header_string.split(',')
#print(header_names)
df = pd.read_csv('csv/part001_inglés_A_Segmentation.csv', names=header_names, header=0)
df_popped = df.drop(columns=['03_Nombre (First name):','04_Apellido (Last name):','frameRate'])
#help(pd.read_csv)

# %%
df_popped

# %%
df_popped.frameRate.unique()

# %%
help(df)

# %%
unique_values_column=df_popped.columns
print(unique_values_column)

# %%
lexTale = df.loc[:,['Word','Translation','corrAnsEspV','corrAnsEngV','lexEsp_key_resp.keys','lexEsp_key_resp.corr','lexEsp_key_resp.rt','lexEng_key_resp.keys','lexEng_key_resp.corr','lexEng_key_resp.rt']]
lexTale

# %%
header_list = list(df)

# %%
header_list

# %%
print(',' .join(header_list))

# %%
header_string = '''Order,Word,Translation,corrAnsEspV,practiceListA,practiceListA0,practiceListA1,practiceListA2,
practiceListA3,practiceList4,practiceListA5,practiceListA6,practiceListA7,conditionA,stimuliListA0,stimuliListA1,
stimuliListA2,stimuliListA3,stimuliListA4,stimuliListA5,stimuliListA6,stimuliListA7,stimuliListA8,stimuliListA9,
stimuliListA10,stimuliListA11,stimuliListA12,stimuliListA13,stimuliListA14,stimuliListA15,stimuliListA16,
stimuliListA17,stimuliListA18,stimuliListA19,stimuliListA20,stimuliListA21,stimuliListA22,stimuliListA23,
stimuliListA24,stimuliListA25,stimuliListA26,stimuliListA27,stimuliListA28,stimuliListA29,stimuliListA30,
stimuliListA31,stimuliListA32,stimuliListA33,stimuliListA34,stimuliListA35,stimuliListA36,stimuliListA37,
stimuliListA38,stimuliListA39,stimuliListA40,stimuliListA41,stimuliListA42,stimuliListA43,stimuliListA44,
stimuliListA45,stimuliListA46,stimuliListA47,syllabification,corrSyl,corrAns,leftKey,rightKey,condition,corrAnsEngV,
questionNum,color,sectionEng,questionTextEng,languageEng,sectionEsp,questionTextEsp,languageEsp,lexEspLoop.thisRepN,
lexEspLoop.thisTrialN,lexEspLoop.thisN,lexEspLoop.thisIndex,pracTarLoop.thisRepN,pracTarLoop.thisTrialN,
pracTarLoop.thisN,pracTarLoop.thisIndex,pracTrialLoop.thisRepN,pracTrialLoop.thisTrialN,pracTrialLoop.thisN,
pracTrialLoop.thisIndex,expTarLoop.thisRepN,expTarLoop.thisTrialN,expTarLoop.thisN,expTarLoop.thisIndex,
expTrialLoop.thisRepN,expTrialLoop.thisTrialN,expTrialLoop.thisN,expTrialLoop.thisIndex,sylPracLoop.thisRepN,
sylPracLoop.thisTrialN,sylPracLoop.thisN,sylPracLoop.thisIndex,syllableLoop.thisRepN,syllableLoop.thisTrialN,
syllableLoop.thisN,syllableLoop.thisIndex,lexEngLoop.thisRepN,lexEngLoop.thisTrialN,lexEngLoop.thisN,
lexEngLoop.thisIndex,trials_blp_hist.thisRepN,trials_blp_hist.thisTrialN,trials_blp_hist.thisN,
trials_blp_hist.thisIndex,trials_blp_hist_2.thisRepN,trials_blp_hist_2.thisTrialN,trials_blp_hist_2.thisN,
trials_blp_hist_2.thisIndex,trials_blp_hist_3.thisRepN,trials_blp_hist_3.thisTrialN,trials_blp_hist_3.thisN,
trials_blp_hist_3.thisIndex,trials_blp_use.thisRepN,trials_blp_use.thisTrialN,trials_blp_use.thisN,
trials_blp_use.thisIndex,trials_blp_prof.thisRepN,trials_blp_prof.thisTrialN,trials_blp_prof.thisN,
trials_blp_prof.thisIndex,trials_blp_att.thisRepN,trials_blp_att.thisTrialN,trials_blp_att.thisN,
trials_blp_att.thisIndex,lexEsp_key_resp.keys,lexEsp_key_resp.corr,lexEsp_key_resp.rt,seg_key_resp.keys,
seg_key_resp.rt,expSyl_key_resp.keys,expSyl_key_resp.corr,expSyl_key_resp.rt,lexEng_key_resp.keys,
lexEng_key_resp.corr,lexEng_key_resp.rt,rating_lang_hist.response,rating_lang_hist.rt,rating_lang_hist_2.response,
rating_lang_hist_2.rt,rating_lang_hist_3.response,rating_lang_hist_3.rt,rating_blp_use.response,rating_blp_use.rt,
rating_lang_prof.response,rating_lang_prof.rt,rating_lang_att.response,rating_lang_att.rt,
01_Participante (Participant):,02_Sesión (Session):,03_Nombre (First name):,04_Apellido (Last name):,
05_Edad (Age):,06_Sexo (Gender):,07_País de nacimiento (Birth country):,08_Lugar de residencia (Place of residence):,
09_Nivel más alto de formación académica (Highest level of formal education):,
10_Idioma preferido (Preferred language):,date,expName,psychopyVersion,frameRate,blah'''

# %%
import pandas as pd
import glob
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns',200)

# %%
df = pd.read_csv('csv/part001_inglés_A_Segmentation.csv')
df.info()
csvList = glob.glob('csv/*.csv')
csvList

# %%
import json
df = pd.read_csv('csv/part001_inglés_A_Segmentation.csv')
originalHeader = list(df)
#print(originalHeader)

# %%
with open('../replacement_map.json', 'r') as json_file:
    replacement_map = json.load(json_file)
#print(replacement_map)

# %%
newHeader = [replacement_map.get(originalName) or originalName for originalName in originalHeader]
#print(newHeader)

# %%
df.to_csv('csv/temp_csv/modified_part001_inglés_A_Segmentation.csv', header=newHeader)

# %% [markdown]
# # Cleaner Version

# %% [markdown]
# import pandas as pd
# import glob
# import json
# import os
#
# pd.set_option('display.max_rows', 500)
# pd.set_option('display.max_columns',200)
# parentDir = os.getcwd()
# #print(parentDir)
# startDir = parentDir +'/csv'
# #print(startDir)
# tempDir = startDir + '/temp_csv'
# #print(tempDir)
# ros.chdir(startDir)
# csvList = glob.glob('*.csv')
# #print(csvList)
# os.chdir(parentDir)
#
# with open('../replacement_map.json', 'r') as json_file:
#     replacement_map = json.load(json_file)
#
# for file in csvList:
#     #print(startDir)
#     #print(file)
#     readDir = startDir + '/' + file
#     #print(readDir)
#     df = pd.read_csv(readDir)
#     originalHeader = list(df)
#     newHeader = [replacement_map.get(originalName) or originalName for originalName in originalHeader]
#     #print(tempDir)
#     #print(file)
#     writeDir = tempDir + '/' + file
#     #print(writeDir)
#     df.to_csv(writeDir, header=newHeader)

# %%
import pandas as pd
import os
import sys
sys.path.append('../../diss_scripts/') #How do I avoid having to add this line?
import dataPreparation

# Change viewing settings for pandas dataframe
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns',200)

# Set some global variables
parentDir = os.getcwd()
startDir = '../../Dissertation_Experiments/segmentation/data/original_data/part_files/'
tempDir = '../../Dissertation_Experiments/segmentation/data/temp_data'
outDir = '../../Dissertation_Experiments/segmentation/data/processed_data/part_files'
statsSegDir = '../../Dissertation_Stats/Syllable_Segmentation/analyze_data/temp_data'
demCols = ['partNum', 'session', 'age', 'gender', 'birthCountry', 'placeResidence', 'education', 'preferLanguage', 'date', 'expName']
lexDuplicates = ['word', 'translation']
lexEsp = ['corrAnsEspV', 'lexRespEsp', 'lexRespEspCorr', 'lexRespEspRT']
lexEng = ['corrAnsEngV', 'lexRespEng', 'lexRespEngCorr', 'lexRespEngRT']
syl = ['syllabification', 'corrSyl', 'corrAns', 'leftKey', 'rightKey', 'condition', 'sylResp', 'sylRespCorr', 'sylRespRT',]
blp = ['questionNum', 'color', 'sectionEng', 'questionTextEng', 'languageEng', 'langHistResp1', 'langHistRT1', 'langHistResp2', 'langHistRT2', 'langHistResp3', 'langHistRT3', 'langUseResp', 'langUseRT', 'langProfResp', 'langProfRT', 'langAttResp', 'langAttRT']
seg = ['fillerCarrier', 'block01', 'block02', 'block03', 'block04', 'block05', 'block06', 'block07', 'block08', 'block09', 'block10', 'block11', 'block12', 'block13', 'block14', 'block15', 'block16', 'block17', 'block18', 'block19', 'block20', 'block21', 'block22', 'block23', 'block24', 'block25', 'block26', 'block27', 'block28', 'block29', 'block30', 'block31', 'block32', 'block33', 'block34', 'block35', 'block36', 'block37', 'block38', 'block39', 'block40', 'block41', 'block42', 'block43', 'block44', 'block45', 'block46', 'block47', 'block48', 'segResp', 'segRespRT']

lexEspCols = [*lexDuplicates,*lexEsp,*demCols]
lexEngCols = [*lexDuplicates,*lexEng,*demCols]
sylCols = [*syl,*demCols]
blpCols = [*blp,*demCols]
segCols = [*seg,*demCols]
segKeepCols = [*lexDuplicates,*lexEsp,*lexEng,*sylCols,*segCols,*blpCols,*demCols]
listOfLists = [demCols,lexEngCols,lexEspCols,sylCols,blpCols,segCols]

# Find all csv files in directory
csvList = dataPreparation.collectFiles(parentDir,startDir)
# Replace all header row names without more appropriate ones
dataPreparation.reMapPandasHeaders('../replacement_map.json',csvList,startDir,tempDir)

# get previously modified csv file as list
csvModList = dataPreparation.collectFiles(parentDir,tempDir)
# Eliminates all unnecessary columns written by PsychoPy
dataPreparation.delPsyPyCols(csvModList,segKeepCols,tempDir, outDir)

# get previously modified csv file as list
csvTaskList = dataPreparation.collectFiles(parentDir,outDir)
# Eliminates all unnecessary columns written by PsychoPy
dataPreparation.delPsyPyCols(csvTaskList,segKeepCols,outDir,statsSegDir)

# %%
statsOutDir = '../../Dissertation_Stats/Syllable_Segmentation/analyze_data/temp_data/'
print(len(segKeepCols))
# get previously modified csv file as list
csvFinalList = dataPreparation.collectFiles(parentDir,statsSegDir)
# Eliminates all unnecessary columns written by PsychoPy
dataPreparation.delPsyPyCols(csvFinalList,sylCols,statsSegDir,statsOutDir)
# Out:
# 127

# %%
csvProcList = dataPreparation.collectFiles(parentDir,outDir)
#print(csvProcList,len(csvProcList))
for file in csvProcList[0:1]:
    readDir = outDir + '/' + file
    df = pd.read_csv(readDir, index_col=0)
    
df
# Out:
#              word     translation  corrAnsEspV fillerCarrier    block01  \
# 0         pladeno              NW          4.0           NaN        NaN
# 1       delantera  first position          1.0           NaN        NaN
# 2      garbardina        raincoat          1.0           NaN        NaN
# 3           terzo              NW          4.0           NaN        NaN
# 4       pellizcar           pinch          1.0           NaN        NaN
# 5        pulmones           lungs          1.0           NaN        NaN
# 6        batillón              NW          4.0           NaN        NaN
# 7          zapato            shoe          1.0           NaN        NaN
# 8     tergiversar         distort          1.0           NaN        NaN
# 9          pésimo         abysmal          1.0           NaN        NaN
# 10         cadeña              NW          4.0           NaN        NaN
# 11          hacha             axe          1.0           NaN        NaN
# 12          antar              NW          4.0           NaN        NaN
# 13         cenefa          edging          1.0           NaN        NaN
# 14      asesinato          murder          1.0           NaN        NaN
# 15          helar          freeze          1.0           NaN        NaN
# 16         yunque           anvil          1.0           NaN        NaN
# 17          regar           water          1.0           NaN        NaN
# 18        abracer              NW          4.0           NaN        NaN
# 19        floroso              NW          4.0           NaN        NaN
# 20           arsa              NW          4.0           NaN        NaN
# 21       brecedad              NW          4.0           NaN        NaN
# 22          ávido            avid          1.0           NaN        NaN
# 23        capillo              NW          4.0           NaN        NaN
# 24         lacayo          lackey          1.0           NaN        NaN
# 25        lampera              NW          4.0           NaN        NaN
# 26         látigo            whip          1.0           NaN        NaN
# 27        bisagra           hinge          1.0           NaN        NaN
# 28      secuestro      kidnapping          1.0           NaN        NaN
# 29      acutación              NW          4.0           NaN        NaN
# 30       merodear           prowl          1.0           NaN        NaN
# 31          decar              NW          4.0           NaN        NaN
# 32        alardio              NW          4.0           NaN        NaN
# 33       pandilla            gang          1.0           NaN        NaN
# 34      fatacidad              NW          4.0           NaN        NaN
# 35          pauca              NW          4.0           NaN        NaN
# 36          aviso          notice          1.0           NaN        NaN
# 37        rompido              NW          4.0           NaN        NaN
# 38           loro          parrot          1.0           NaN        NaN
# 39        granuja          rascal          1.0           NaN        NaN
# 40     estornudar          sneeze          1.0           NaN        NaN
# 41          torpe          clumsy          1.0           NaN        NaN
# 42       alfombra          carpet          1.0           NaN        NaN
# 43       rebuscar         rummage          1.0           NaN        NaN
# 44        cadallo              NW          4.0           NaN        NaN
# 45         canela        cinnamon          1.0           NaN        NaN
# 46        cuchara           spoon          1.0           NaN        NaN
# 47       jilguero       goldfinch          1.0           NaN        NaN
# 48       martillo          hammer          1.0           NaN        NaN
# 49       cartinar              NW          4.0           NaN        NaN
# 50         ladrón           thief          1.0           NaN        NaN
# 51          ganar             win          1.0           NaN        NaN
# 52        flamida              NW          4.0           NaN        NaN
# 53        candado         padlock          1.0           NaN        NaN
# 54         camisa           shirt          1.0           NaN        NaN
# 55         vegada              NW          4.0           NaN        NaN
# 56       fomentar         promote          1.0           NaN        NaN
# 57          nevar            snow          1.0           NaN        NaN
# 58          musgo            moss          1.0           NaN        NaN
# 59         tacaño          stingy          1.0           NaN        NaN
# 60        plaudir              NW          4.0           NaN        NaN
# 61          besar            kiss          1.0           NaN        NaN
# 62          matar            kill          1.0           NaN        NaN
# 63           seda            silk          1.0           NaN        NaN
# 64          flaco          skinny          1.0           NaN        NaN
# 65      esposante              NW          4.0           NaN        NaN
# 66      orgulloso           proud          1.0           NaN        NaN
# 67       bizcocho            cake          1.0           NaN        NaN
# 68         hacido              NW          4.0           NaN        NaN
# 69        cabello            hair          1.0           NaN        NaN
# 70         alegre        cheerful          1.0           NaN        NaN
# 71      engatusar          cajole          1.0           NaN        NaN
# 72         temblo              NW          4.0           NaN        NaN
# 73    polvoriento           dusty          1.0           NaN        NaN
# 74       pemición              NW          4.0           NaN        NaN
# 75       hervidor          kettle          1.0           NaN        NaN
# 76         cintro              NW          4.0           NaN        NaN
# 77          yacer             lie          1.0           NaN        NaN
# 78           atar             tie          1.0           NaN        NaN
# 79        tiburón           shark          1.0           NaN        NaN
# 80       frondoso           leafy          1.0           NaN        NaN
# 81        tropaje              NW          4.0           NaN        NaN
# 82        hormiga             ant          1.0           NaN        NaN
# 83           pozo            well          1.0           NaN        NaN
# 84      empirador              NW          4.0           NaN        NaN
# 85         guante           glove          1.0           NaN        NaN
# 86         escuto              NW          4.0           NaN        NaN
# 87           laud            lute          1.0           NaN        NaN
# 88         barato           cheap          1.0           NaN        NaN
# 89          grodo              NW          4.0           NaN        NaN
# 90     acantilado           cliff          1.0           NaN        NaN
# 91          prisa           hurry          1.0           NaN        NaN
# 92         clavel       carnation          1.0           NaN        NaN
# 93            NaN             NaN          NaN           NaN        NaN
# 94            NaN             NaN          NaN           NaN        NaN
# 95            NaN             NaN          NaN           NaN        NaN
# 96            NaN             NaN          NaN           NaN        NaN
# 97            NaN             NaN          NaN           NaN        NaN
# 98            NaN             NaN          NaN           NaN        NaN
# 99            NaN             NaN          NaN           NaN        NaN
# 100           NaN             NaN          NaN           NaN        NaN
# 101           NaN             NaN          NaN           NaN        NaN
# 102           NaN             NaN          NaN           NaN        NaN
# 103           NaN             NaN          NaN           NaN        NaN
# 104           NaN             NaN          NaN           NaN        NaN
# 105           NaN             NaN          NaN           NaN        NaN
# 106           NaN             NaN          NaN           NaN        NaN
# 107           NaN             NaN          NaN           NaN        NaN
# 108           NaN             NaN          NaN           NaN        NaN
# 109           NaN             NaN          NaN           NaN        NaN
# 110           NaN             NaN          NaN           NaN        NaN
# 177           NaN             NaN          NaN           NaN        NaN
# 178           NaN             NaN          NaN           NaN        NaN
# 179           NaN             NaN          NaN           NaN        NaN
# 180           NaN             NaN          NaN           NaN        NaN
# 181           NaN             NaN          NaN   filleritem7     legajo
# 182           NaN             NaN          NaN   filleritem6     pileta
# 183           NaN             NaN          NaN   filleritem3   cambiazo
# 184           NaN             NaN          NaN   carrierItem  rosquilla
# 185           NaN             NaN          NaN   filleritem2   lenguaje
# 186           NaN             NaN          NaN   filleritem1   pantalla
# 187           NaN             NaN          NaN   filleritem8     veleta
# 188           NaN             NaN          NaN   filleritem5     putada
# 189           NaN             NaN          NaN   filleritem9    pitillo
# 190           NaN             NaN          NaN   filleritem4    campiña
# 191           NaN             NaN          NaN     targetSyl        ros
# 192           NaN             NaN          NaN   filleritem4    campiña
# 193           NaN             NaN          NaN   filleritem2   lenguaje
# 194           NaN             NaN          NaN   filleritem6     pileta
# 195           NaN             NaN          NaN   filleritem7     legajo
# 196           NaN             NaN          NaN   filleritem9    pitillo
# 197           NaN             NaN          NaN   filleritem3   cambiazo
# 198           NaN             NaN          NaN   filleritem8     veleta
# 199           NaN             NaN          NaN   filleritem1   pantalla
# 200           NaN             NaN          NaN   filleritem5     putada
# 201           NaN             NaN          NaN   carrierItem  rosquilla
# 202           NaN             NaN          NaN     targetSyl        ros
# 203           NaN             NaN          NaN   carrierItem  rosquilla
# 204           NaN             NaN          NaN   filleritem4    campiña
# 205           NaN             NaN          NaN   filleritem8     veleta
# 206           NaN             NaN          NaN   filleritem6     pileta
# 207           NaN             NaN          NaN   filleritem5     putada
# 208           NaN             NaN          NaN   filleritem3   cambiazo
# 209           NaN             NaN          NaN   filleritem9    pitillo
# 210           NaN             NaN          NaN   filleritem2   lenguaje
# 211           NaN             NaN          NaN   filleritem1   pantalla
# 212           NaN             NaN          NaN   filleritem7     legajo
# 213           NaN             NaN          NaN     targetSyl        ros
# 214           NaN             NaN          NaN   filleritem8     veleta
# 215           NaN             NaN          NaN   filleritem1   pantalla
# 216           NaN             NaN          NaN   filleritem3   cambiazo
# 217           NaN             NaN          NaN   filleritem5     putada
# 218           NaN             NaN          NaN   filleritem2   lenguaje
# 219           NaN             NaN          NaN   filleritem4    campiña
# 220           NaN             NaN          NaN   filleritem9    pitillo
# 221           NaN             NaN          NaN   filleritem7     legajo
# 222           NaN             NaN          NaN   filleritem6     pileta
# 223           NaN             NaN          NaN   carrierItem  rosquilla
# 224           NaN             NaN          NaN     targetSyl        ros
# 225           NaN             NaN          NaN   filleritem3   cambiazo
# 226           NaN             NaN          NaN   filleritem9    pitillo
# 227           NaN             NaN          NaN   filleritem4    campiña
# 228           NaN             NaN          NaN   filleritem5     putada
# 229           NaN             NaN          NaN   filleritem6     pileta
# 230           NaN             NaN          NaN   filleritem8     veleta
# 231           NaN             NaN          NaN   carrierItem  rosquilla
# 232           NaN             NaN          NaN   filleritem7     legajo
# 233           NaN             NaN          NaN   filleritem2   lenguaje
# 234           NaN             NaN          NaN   filleritem1   pantalla
# 235           NaN             NaN          NaN     targetSyl        ros
# 236           NaN             NaN          NaN   filleritem7     legajo
# 237           NaN             NaN          NaN   filleritem6     pileta
# 238           NaN             NaN          NaN   carrierItem  rosquilla
# 239           NaN             NaN          NaN   filleritem4    campiña
# 240           NaN             NaN          NaN   filleritem8     veleta
# 241           NaN             NaN          NaN   filleritem2   lenguaje
# 242           NaN             NaN          NaN   filleritem1   pantalla
# 243           NaN             NaN          NaN   filleritem3   cambiazo
# 244           NaN             NaN          NaN   filleritem9    pitillo
# 245           NaN             NaN          NaN   filleritem5     putada
# 246           NaN             NaN          NaN     targetSyl        ros
# 247           NaN             NaN          NaN   carrierItem  rosquilla
# 248           NaN             NaN          NaN   filleritem7     legajo
# 249           NaN             NaN          NaN   filleritem1   pantalla
# ..            ...             ...          ...           ...        ...
# 623           NaN             NaN          NaN   carrierItem  rosquilla
# 624           NaN             NaN          NaN   filleritem5     putada
# 625           NaN             NaN          NaN   filleritem9    pitillo
# 626           NaN             NaN          NaN   filleritem7     legajo
# 627           NaN             NaN          NaN   filleritem4    campiña
# 628           NaN             NaN          NaN   filleritem8     veleta
# 629           NaN             NaN          NaN   filleritem2   lenguaje
# 630           NaN             NaN          NaN   filleritem1   pantalla
# 631           NaN             NaN          NaN     targetSyl        ros
# 632           NaN             NaN          NaN   filleritem7     legajo
# 633           NaN             NaN          NaN   filleritem4    campiña
# 634           NaN             NaN          NaN   filleritem8     veleta
# 635           NaN             NaN          NaN   filleritem2   lenguaje
# 636           NaN             NaN          NaN   filleritem6     pileta
# 637           NaN             NaN          NaN   filleritem1   pantalla
# 638           NaN             NaN          NaN   filleritem3   cambiazo
# 639           NaN             NaN          NaN   carrierItem  rosquilla
# 640           NaN             NaN          NaN   filleritem9    pitillo
# 641           NaN             NaN          NaN   filleritem5     putada
# 642           NaN             NaN          NaN     targetSyl        ros
# 643           NaN             NaN          NaN   filleritem7     legajo
# 644           NaN             NaN          NaN   filleritem9    pitillo
# 645           NaN             NaN          NaN   filleritem8     veleta
# 646           NaN             NaN          NaN   filleritem6     pileta
# 647           NaN             NaN          NaN   filleritem1   pantalla
# 648           NaN             NaN          NaN   filleritem5     putada
# 649           NaN             NaN          NaN   filleritem2   lenguaje
# 650           NaN             NaN          NaN   carrierItem  rosquilla
# 651           NaN             NaN          NaN   filleritem4    campiña
# 652           NaN             NaN          NaN   filleritem3   cambiazo
# 653           NaN             NaN          NaN     targetSyl        ros
# 654           NaN             NaN          NaN   filleritem2   lenguaje
# 655           NaN             NaN          NaN   filleritem8     veleta
# 656           NaN             NaN          NaN   filleritem9    pitillo
# 657           NaN             NaN          NaN   filleritem5     putada
# 658           NaN             NaN          NaN   filleritem4    campiña
# 659           NaN             NaN          NaN   carrierItem  rosquilla
# 660           NaN             NaN          NaN   filleritem6     pileta
# 661           NaN             NaN          NaN   filleritem3   cambiazo
# 662           NaN             NaN          NaN   filleritem1   pantalla
# 663           NaN             NaN          NaN   filleritem7     legajo
# 664           NaN             NaN          NaN     targetSyl        ros
# 665           NaN             NaN          NaN   filleritem6     pileta
# 666           NaN             NaN          NaN   carrierItem  rosquilla
# 667           NaN             NaN          NaN   filleritem2   lenguaje
# 668           NaN             NaN          NaN   filleritem1   pantalla
# 669           NaN             NaN          NaN   filleritem3   cambiazo
# 670           NaN             NaN          NaN   filleritem7     legajo
# 671           NaN             NaN          NaN   filleritem4    campiña
# 672           NaN             NaN          NaN   filleritem8     veleta
# 673           NaN             NaN          NaN   filleritem5     putada
# 674           NaN             NaN          NaN   filleritem9    pitillo
# 675           NaN             NaN          NaN     targetSyl        ros
# 676           NaN             NaN          NaN   filleritem4    campiña
# 677           NaN             NaN          NaN   filleritem9    pitillo
# 678           NaN             NaN          NaN   filleritem2   lenguaje
# 679           NaN             NaN          NaN   filleritem3   cambiazo
# 680           NaN             NaN          NaN   filleritem5     putada
# 681           NaN             NaN          NaN   carrierItem  rosquilla
# 682           NaN             NaN          NaN   filleritem7     legajo
# 683           NaN             NaN          NaN   filleritem6     pileta
# 684           NaN             NaN          NaN   filleritem8     veleta
# 685           NaN             NaN          NaN   filleritem1   pantalla
# 686           NaN             NaN          NaN     targetSyl        ros
# 687           NaN             NaN          NaN   filleritem9    pitillo
# 688           NaN             NaN          NaN   filleritem6     pileta
# 689           NaN             NaN          NaN   filleritem3   cambiazo
# 690           NaN             NaN          NaN   filleritem4    campiña
# 691           NaN             NaN          NaN   filleritem5     putada
# 692           NaN             NaN          NaN   filleritem2   lenguaje
# 693           NaN             NaN          NaN   filleritem8     veleta
# 694           NaN             NaN          NaN   carrierItem  rosquilla
# 695           NaN             NaN          NaN   filleritem1   pantalla
# 696           NaN             NaN          NaN   filleritem7     legajo
# 697           NaN             NaN          NaN     targetSyl        ros
# 698           NaN             NaN          NaN   filleritem6     pileta
# 699           NaN             NaN          NaN   filleritem1   pantalla
# 700           NaN             NaN          NaN   filleritem5     putada
# 701           NaN             NaN          NaN   filleritem9    pitillo
# 702           NaN             NaN          NaN   filleritem3   cambiazo
# 703           NaN             NaN          NaN   filleritem8     veleta
# 704           NaN             NaN          NaN   filleritem2   lenguaje
# 705           NaN             NaN          NaN   filleritem7     legajo
# 706           NaN             NaN          NaN   carrierItem  rosquilla
# 707           NaN             NaN          NaN   filleritem4    campiña
# 708           NaN             NaN          NaN     targetSyl        ros
# 709           NaN             NaN          NaN           NaN        NaN
# 710           NaN             NaN          NaN           NaN        NaN
# 711           NaN             NaN          NaN           NaN        NaN
# 712           NaN             NaN          NaN           NaN        NaN
# 713           NaN             NaN          NaN           NaN        NaN
# 714           NaN             NaN          NaN           NaN        NaN
# 715           NaN             NaN          NaN           NaN        NaN
# 716           NaN             NaN          NaN           NaN        NaN
# 717           NaN             NaN          NaN           NaN        NaN
# 718           NaN             NaN          NaN           NaN        NaN
# 719           NaN             NaN          NaN           NaN        NaN
# 720           NaN             NaN          NaN           NaN        NaN
# 721           NaN             NaN          NaN           NaN        NaN
# 722           NaN             NaN          NaN           NaN        NaN
# 723           NaN             NaN          NaN           NaN        NaN
# 724           NaN             NaN          NaN           NaN        NaN
# 725           NaN             NaN          NaN           NaN        NaN
# 726           NaN             NaN          NaN           NaN        NaN
# 727           NaN             NaN          NaN           NaN        NaN
Hermosillo  Un poco de universidad        español  2019_Sep_27_1824
# 859     Hermosillo  Un poco de universidad        español  2019_Sep_27_1824
# 860     Hermosillo  Un poco de universidad        español  2019_Sep_27_1824
# 861     Hermosillo  Un poco de universidad        español  2019_Sep_27_1824
# 862     Hermosillo  Un poco de universidad        español  2019_Sep_27_1824
# 863     Hermosillo  Un poco de universidad        español  2019_Sep_27_1824
# 864     Hermosillo  Un poco de universidad        español  2019_Sep_27_1824
# 865     Hermosillo  Un poco de universidad        español  2019_Sep_27_1824
# 866     Hermosillo  Un poco de universidad        español  2019_Sep_27_1824
# 867     Hermosillo  Un poco de universidad        español  2019_Sep_27_1824
# 868     Hermosillo  Un poco de universidad        español  2019_Sep_27_1824
# 869     Hermosillo  Un poco de universidad        español  2019_Sep_27_1824
# 870     Hermosillo  Un poco de universidad        español  2019_Sep_27_1824
# 871     Hermosillo  Un poco de universidad        español  2019_Sep_27_1824
# 872     Hermosillo  Un poco de universidad        español  2019_Sep_27_1824
#
#           expName
# 0    Segmentation
# 1    Segmentation
# 2    Segmentation
# 3    Segmentation
# 4    Segmentation
# 5    Segmentation
# 6    Segmentation
# 7    Segmentation
# 8    Segmentation
# 9    Segmentation
# 10   Segmentation
# 11   Segmentation
# 12   Segmentation
# 13   Segmentation
# 14   Segmentation
# 15   Segmentation
# 16   Segmentation
# 17   Segmentation
# 18   Segmentation
# 19   Segmentation
# 20   Segmentation
# 21   Segmentation
# 22   Segmentation
# 23   Segmentation
# 24   Segmentation
# 25   Segmentation
# 26   Segmentation
# 27   Segmentation
# 28   Segmentation
# 29   Segmentation
# 30   Segmentation
# 31   Segmentation
# 32   Segmentation
# 33   Segmentation
# 34   Segmentation
# 35   Segmentation
# 36   Segmentation
# 37   Segmentation
# 38   Segmentation
# 39   Segmentation
# 40   Segmentation
# 41   Segmentation
# 42   Segmentation
# 43   Segmentation
# 44   Segmentation
# 45   Segmentation
# 46   Segmentation
# 47   Segmentation
# 48   Segmentation
# 49   Segmentation
# 50   Segmentation
# 51   Segmentation
# 52   Segmentation
# 53   Segmentation
# 54   Segmentation
# 55   Segmentation
# 56   Segmentation
# 57   Segmentation
# 58   Segmentation
# 59   Segmentation
# 60   Segmentation
# 61   Segmentation
# 62   Segmentation
# 63   Segmentation
# 64   Segmentation
# 65   Segmentation
# 66   Segmentation
# 67   Segmentation
# 68   Segmentation
# 69   Segmentation
# 70   Segmentation
# 71   Segmentation
# 72   Segmentation
# 73   Segmentation
# 74   Segmentation
# 75   Segmentation
# 76   Segmentation
# 77   Segmentation
# 78   Segmentation
# 79   Segmentation
# 80   Segmentation
# 81   Segmentation
# 82   Segmentation
# 83   Segmentation
# 84   Segmentation
# 85   Segmentation
# 86   Segmentation
# 87   Segmentation
# 88   Segmentation
# 89   Segmentation
# 90   Segmentation
# 91   Segmentation
# 92   Segmentation
# 93   Segmentation
# 94   Segmentation
# 95   Segmentation
# 96   Segmentation
# 97   Segmentation
# 98   Segmentation
# 99   Segmentation
# 100  Segmentation
# 101  Segmentation
# 102  Segmentation
# 103  Segmentation
# 104  Segmentation
# 105  Segmentation
# 106  Segmentation
# 107  Segmentation
# 108  Segmentation
# 109  Segmentation
# 110  Segmentation
# 111  Segmentation
# 112  Segmentation
# 113  Segmentation
# 114  Segmentation
# 115  Segmentation
# 116  Segmentation
# 117  Segmentation
# 118  Segmentation
# 119  Segmentation
# 120  Segmentation
# 121  Segmentation
# 122  Segmentation
# 123  Segmentation
# 124  Segmentation
# 125  Segmentation
# 126  Segmentation
# 127  Segmentation
# 128  Segmentation
# 129  Segmentation
# 130  Segmentation
# 131  Segmentation
# 132  Segmentation
# 133  Segmentation
# 134  Segmentation
# 135  Segmentation
# 136  Segmentation
# 137  Segmentation
# 138  Segmentation
# 139  Segmentation
# 140  Segmentation
# 141  Segmentation
# 142  Segmentation
# 143  Segmentation
# 144  Segmentation
# 145  Segmentation
# 146  Segmentation
# 147  Segmentation
# 148  Segmentation
# 149  Segmentation
# 150  Segmentation
# 151  Segmentation
# 152  Segmentation
# 153  Segmentation
# 154  Segmentation
# 155  Segmentation
# 156  Segmentation
# 157  Segmentation
# 158  Segmentation
# 159  Segmentation
# 160  Segmentation
# 161  Segmentation
# 162  Segmentation
# 163  Segmentation
# 164  Segmentation
# 165  Segmentation
# 166  Segmentation
# 167  Segmentation
# 168  Segmentation
# 169  Segmentation
# 170  Segmentation
# 171  Segmentation
# 172  Segmentation
# 173  Segmentation
# 174  Segmentation
# 175  Segmentation
# 176  Segmentation
# 177  Segmentation
# 178  Segmentation
# 179  Segmentation
# 180  Segmentation
# 181  Segmentation
# 182  Segmentation
# 183  Segmentation
# 184  Segmentation
# 185  Segmentation
# 186  Segmentation
# 187  Segmentation
# 188  Segmentation
# 189  Segmentation
# 190  Segmentation
# 191  Segmentation
# 192  Segmentation
# 193  Segmentation
# 194  Segmentation
# 195  Segmentation
# 196  Segmentation
# 197  Segmentation
# 198  Segmentation
# 199  Segmentation
# 200  Segmentation
# 201  Segmentation
# 202  Segmentation
# 203  Segmentation
# 204  Segmentation
# 205  Segmentation
# 206  Segmentation
# 207  Segmentation
# 208  Segmentation
# 209  Segmentation
# 210  Segmentation
# 211  Segmentation
# 212  Segmentation
# 213  Segmentation
# 214  Segmentation
# 215  Segmentation
# 216  Segmentation
# 217  Segmentation
# 218  Segmentation
# 219  Segmentation
# 220  Segmentation
# 221  Segmentation
# 222  Segmentation
# 223  Segmentation
# 224  Segmentation
# 225  Segmentation
# 226  Segmentation
# 227  Segmentation
# 228  Segmentation
# 229  Segmentation
# 230  Segmentation
# 231  Segmentation
# 232  Segmentation
# 233  Segmentation
# 234  Segmentation
# 235  Segmentation
# 236  Segmentation
# 237  Segmentation
# 238  Segmentation
# 239  Segmentation
# 240  Segmentation
# 241  Segmentation
# 242  Segmentation
# 243  Segmentation
# 244  Segmentation
# 245  Segmentation
# 246  Segmentation
# 247  Segmentation
# 248  Segmentation
# 249  Segmentation
# ..            ...
# 623  Segmentation
# 624  Segmentation
# 625  Segmentation
# 626  Segmentation
# 627  Segmentation
# 628  Segmentation
# 629  Segmentation
# 630  Segmentation
# 631  Segmentation
# 632  Segmentation
# 633  Segmentation
# 634  Segmentation
# 635  Segmentation
# 636  Segmentation
# 637  Segmentation
# 638  Segmentation
# 639  Segmentation
# 640  Segmentation
# 641  Segmentation
# 642  Segmentation
# 643  Segmentation
# 644  Segmentation
# 645  Segmentation
# 646  Segmentation
# 647  Segmentation
# 648  Segmentation
# 649  Segmentation
# 650  Segmentation
# 651  Segmentation
# 652  Segmentation
# 653  Segmentation
# 654  Segmentation
# 655  Segmentation
# 656  Segmentation
# 657  Segmentation
# 658  Segmentation
# 659  Segmentation
# 660  Segmentation
# 661  Segmentation
# 662  Segmentation
# 663  Segmentation
# 664  Segmentation
# 665  Segmentation
# 666  Segmentation
# 667  Segmentation
# 668  Segmentation
# 669  Segmentation
# 670  Segmentation
# 671  Segmentation
# 672  Segmentation
# 673  Segmentation
# 674  Segmentation
# 675  Segmentation
# 676  Segmentation
# 677  Segmentation
# 678  Segmentation
# 679  Segmentation
# 680  Segmentation
# 681  Segmentation
# 682  Segmentation
# 683  Segmentation
# 684  Segmentation
# 685  Segmentation
# 686  Segmentation
# 687  Segmentation
# 688  Segmentation
# 689  Segmentation
# 690  Segmentation
# 691  Segmentation
# 692  Segmentation
# 693  Segmentation
# 694  Segmentation
# 695  Segmentation
# 696  Segmentation
# 697  Segmentation
# 698  Segmentation
# 699  Segmentation
# 700  Segmentation
# 701  Segmentation
# 702  Segmentation
# 703  Segmentation
# 704  Segmentation
# 705  Segmentation
# 706  Segmentation
# 707  Segmentation
# 708  Segmentation
# 709  Segmentation
# 710  Segmentation
# 711  Segmentation
# 712  Segmentation
# 713  Segmentation
# 714  Segmentation
# 715  Segmentation
# 716  Segmentation
# 717  Segmentation
# 718  Segmentation
# 719  Segmentation
# 720  Segmentation
# 721  Segmentation
# 722  Segmentation
# 723  Segmentation
# 724  Segmentation
# 725  Segmentation
# 726  Segmentation
# 727  Segmentation
# 728  Segmentation
# 729  Segmentation
# 730  Segmentation
# 731  Segmentation
# 732  Segmentation
# 733  Segmentation
# 734  Segmentation
# 735  Segmentation
# 736  Segmentation
# 737  Segmentation
# 738  Segmentation
# 739  Segmentation
# 740  Segmentation
# 741  Segmentation
# 742  Segmentation
# 743  Segmentation
# 744  Segmentation
# 745  Segmentation
# 746  Segmentation
# 747  Segmentation
# 748  Segmentation
# 749  Segmentation
# 750  Segmentation
# 751  Segmentation
# 752  Segmentation
# 753  Segmentation
# 754  Segmentation
# 755  Segmentation
# 756  Segmentation
# 757  Segmentation
# 758  Segmentation
# 759  Segmentation
# 760  Segmentation
# 761  Segmentation
# 762  Segmentation
# 763  Segmentation
# 764  Segmentation
# 765  Segmentation
# 766  Segmentation
# 767  Segmentation
# 768  Segmentation
# 769  Segmentation
# 770  Segmentation
# 771  Segmentation
# 772  Segmentation
# 773  Segmentation
# 774  Segmentation
# 775  Segmentation
# 776  Segmentation
# 777  Segmentation
# 778  Segmentation
# 779  Segmentation
# 780  Segmentation
# 781  Segmentation
# 782  Segmentation
# 783  Segmentation
# 784  Segmentation
# 785  Segmentation
# 786  Segmentation
# 787  Segmentation
# 788  Segmentation
# 789  Segmentation
# 790  Segmentation
# 791  Segmentation
# 792  Segmentation
# 793  Segmentation
# 794  Segmentation
# 795  Segmentation
# 796  Segmentation
# 797  Segmentation
# 798  Segmentation
# 799  Segmentation
# 800  Segmentation
# 801  Segmentation
# 802  Segmentation
# 803  Segmentation
# 804  Segmentation
# 805  Segmentation
# 806  Segmentation
# 807  Segmentation
# 808  Segmentation
# 809  Segmentation
# 810  Segmentation
# 811  Segmentation
# 812  Segmentation
# 813  Segmentation
# 814  Segmentation
# 815  Segmentation
# 816  Segmentation
# 817  Segmentation
# 818  Segmentation
# 819  Segmentation
# 820  Segmentation
# 821  Segmentation
# 822  Segmentation
# 823  Segmentation
# 824  Segmentation
# 825  Segmentation
# 826  Segmentation
# 827  Segmentation
# 828  Segmentation
# 829  Segmentation
# 830  Segmentation
# 831  Segmentation
# 832  Segmentation
# 833  Segmentation
# 834  Segmentation
# 835  Segmentation
# 836  Segmentation
# 837  Segmentation
# 838  Segmentation
# 839  Segmentation
# 840  Segmentation
# 841  Segmentation
# 842  Segmentation
# 843  Segmentation
# 844  Segmentation
# 845  Segmentation
# 846  Segmentation
# 847  Segmentation
# 848  Segmentation
# 849  Segmentation
# 850  Segmentation
# 851  Segmentation
# 852  Segmentation
# 853  Segmentation
# 854  Segmentation
# 855  Segmentation
# 856  Segmentation
# 857  Segmentation
# 858  Segmentation
# 859  Segmentation
# 860  Segmentation
# 861  Segmentation
# 862  Segmentation
# 863  Segmentation
# 864  Segmentation
# 865  Segmentation
# 866  Segmentation
# 867  Segmentation
# 868  Segmentation
# 869  Segmentation
# 870  Segmentation
# 871  Segmentation
# 872  Segmentation
#
# [873 rows x 97 columns]

# %% [markdown]
# csvModList = dataPreparation.collectFiles(parentDir,tempDir)
# #print(len(csvModList))
# #dataPreparation.reMapPandasHeaders('../replacement_map.json',csvModList,tempDir,outDir)
# for file in csvModList:
#         readDir = tempDir + '/' + file
#         df = pd.read_csv(readDir, index_col=0)
#         #originalHeader = list(df)
#         #newHeader = [replacement_map.get(originalName) or originalName for originalName in originalHeader]
#
#         #df.to_csv(writeDir, header=newHeader)
#         #print(originalHeader, len(originalHeader))
#         new_df = df.loc[:, df.columns.isin(segKeepCols)]
#         #print(new_df.columns)
#         writeDir = outDir + '/' + file
#         #print(writeDir)
#         new_df.to_csv(writeDir)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 873 entries, 0 to 872
# Data columns (total 100 columns):
# word               156 non-null object
# translation        93 non-null object
# corrAnsEspV        93 non-null float64
# fillerCarrier      528 non-null object
# block01            528 non-null object
# block02            528 non-null object
# block03            528 non-null object
# block04            528 non-null object
# block05            528 non-null object
# block06            528 non-null object
# block07            528 non-null object
# block08            528 non-null object
# block09            528 non-null object
# block10            528 non-null object
# block11            528 non-null object
# block12            528 non-null object
# block13            528 non-null object
# block14            528 non-null object
# block15            528 non-null object
# block16            528 non-null object
# block17            528 non-null object
# block18            528 non-null object
# block19            528 non-null object
# block20            528 non-null object
# block21            528 non-null object
# block22            528 non-null object
# block23            528 non-null object
# block24            528 non-null object
# block25            528 non-null object
# block26            528 non-null object
# block27            528 non-null object
# block28            528 non-null object
# block29            528 non-null object
# block30            528 non-null object
# block31            528 non-null object
# block32            528 non-null object
# block33            528 non-null object
# block34            528 non-null object
# block35            528 non-null object
# block36            528 non-null object
# block37            528 non-null object
# block38            528 non-null object
# block39            528 non-null object
# block40            528 non-null object
# block41            528 non-null object
# block42            528 non-null object
# block43            528 non-null object
# block44            528 non-null object
# block45            528 non-null object
# block46            528 non-null object
# block47            528 non-null object
# block48            528 non-null object
# syllabification    58 non-null object
# corrSyl            58 non-null object
# corrAns            58 non-null float64
# leftKey            58 non-null object
# rightKey           58 non-null object
# condition          58 non-null object
# corrAnsEngV        63 non-null float64
# questionNum        43 non-null object
# color              43 non-null object
# sectionEng         43 non-null object
# questionTextEng    43 non-null object
# languageEng        43 non-null object
# sectionEsp         43 non-null object
# questionTextEsp    43 non-null object
# languageEsp        43 non-null object
# lexRespEsp         93 non-null float64
# lexRespEspCorr     93 non-null float64
# lexRespEspRT       93 non-null float64
# segResp            480 non-null object
# segRespRT          47 non-null float64
# sylResp            48 non-null float64
# sylRespCorr        48 non-null float64
# sylRespRT          48 non-null float64
# lexRespEng         63 non-null float64
# lexRespEngCorr     63 non-null float64
# lexRespEngRT       63 non-null float64
# langHistResp1      2 non-null float64
# langHistRT1        2 non-null float64
# langHistResp2      2 non-null float64
# langHistRT2        2 non-null float64
# langHistResp3      8 non-null float64
# langHistRT3        8 non-null float64
# langUseResp        15 non-null float64
# langUseRT          15 non-null float64
# langProfResp       8 non-null float64
# langProfRT         8 non-null float64
# langAttResp        8 non-null float64
# langAttRT          8 non-null float64
# partNum            873 non-null object
# session            873 non-null object
# age                873 non-null int64
# gender             873 non-null object
# birthCountry       873 non-null object
# placeResidence     873 non-null object
# education          873 non-null object
# preferLanguage     873 non-null object
# date               873 non-null object
# expName            873 non-null object
# dtypes: float64(25), int64(1), object(74)
# memory usage: 688.9+ KB

# %% [markdown]
# #testing block only
# csvModList = dataPreparation.collectFiles(parentDir,tempDir)
# print(len(csvModList))
# #dataPreparation.reMapPandasHeaders('../replacement_map.json',csvModList,tempDir,outDir)
# for file in csvModList[0:1]:
#         readDir = tempDir + '/' + file
#         df = pd.read_csv(readDir, index_col=0)
#         #originalHeader = list(df)
#         #newHeader = [replacement_map.get(originalName) or originalName for originalName in originalHeader]
#         #writeDir = tempDir + '/' + file
#         #df.to_csv(writeDir, header=newHeader)
#         #print(originalHeader, len(originalHeader))
#         new_df = df.loc[:, df.columns.isin(segKeepCols)]
#         print(new_df.columns)

# %% [markdown]
# #Not needed in final code at this location. Added to global variables
# keepCols = ['word', 'translation', 'corrAnsEspV', 'fillerCarrier', 'block01', 'block02', 'block03', 'block04', 'block05', 'block06', 'block07', 'block08', 'block09', 'block10', 'block11', 'block12', 'block13', 'block14', 'block15', 'block16', 'block17', 'block18', 'block19', 'block20', 'block21', 'block22', 'block23', 'block24', 'block25', 'block26', 'block27', 'block28', 'block29', 'block30', 'block31', 'block32', 'block33', 'block34', 'block35', 'block36', 'block37', 'block38', 'block39', 'block40', 'block41', 'block42', 'block43', 'block44', 'block45', 'block46', 'block47', 'block48', 'syllabification', 'corrSyl', 'corrAns', 'leftKey', 'rightKey', 'condition', 'corrAnsEngV', 'questionNum', 'color', 'sectionEng', 'questionTextEng', 'languageEng', 'sectionEsp', 'questionTextEsp', 'languageEsp', 'lexRespEsp', 'lexRespEspCorr', 'lexRespEspRT', 'segResp', 'segRespRT', 'sylResp', 'sylRespCorr', 'sylRespRT', 'lexRespEng', 'lexRespEngCorr', 'lexRespEngRT', 'langHistResp1', 'langHistRT1', 'langHistResp2', 'langHistRT2', 'langHistResp3', 'langHistRT3', 'langUseResp', 'langUseRT', 'langProfResp', 'langProfRT', 'langAttResp', 'langAttRT', 'partNum', 'session', 'firstName', 'lastName', 'age', 'gender', 'birthCountry', 'placeResidence', 'education', 'preferLanguage', 'date', 'expName']
# #print(keepCols, len(keepCols))

# %%
import os
os.chdir('/Users/drakeasberry/github/Dissertation/')
# !export PYTHONPATH=.
# !pwd
# Out:
# /Users/drakeasberry/github/Dissertation

# %%
# Prepare all files from experiment and run R analysis
import os
#import sys
#sys.path.append('../../diss_scripts/') # commented out after Julian suggestion
from diss_scripts import dataPreparation
import requests

#pandas settings
#pd.set_option('display.max_rows', 500)
#pd.set_option('display.max_columns',200)

# Set some global variables
parentDir = os.getcwd()
print(parentDir)
startDir = 'Dissertation_Experiments/segmentation/data/original_data/part_files/'
tempDir = 'Dissertation_Experiments/segmentation/data/temp_data'
outDir = 'Dissertation_Experiments/segmentation/data/processed_data/part_files'
statsSegDir = 'Dissertation_Stats/Syllable_Segmentation/analyze_data/temp_data'
statsOutDir = 'Dissertation_Stats/Syllable_Segmentation/analyze_data/rFiles'

# Create lists for separate file needed to analyze all experiments
demCols = ['partNum', 'session', 'age', 'gender', 'birthCountry', 'placeResidence', 'education', 'preferLanguage',
           'date', 'expName']
lexDuplicates = ['word', 'translation']
lexEsp = ['corrAnsEspV', 'lexRespEsp', 'lexRespEspCorr', 'lexRespEspRT']
lexEng = ['corrAnsEngV', 'lexRespEng', 'lexRespEngCorr', 'lexRespEngRT']
syl = ['syllabification', 'corrSyl', 'corrAns', 'leftKey', 'rightKey', 'condition', 'sylResp', 'sylRespCorr',
       'sylRespRT', ]
blp = ['questionNum', 'color', 'sectionEng', 'questionTextEng', 'languageEng', 'langHistResp1', 'langHistRT1',
       'langHistResp2', 'langHistRT2', 'langHistResp3', 'langHistRT3', 'langUseResp', 'langUseRT', 'langProfResp',
       'langProfRT', 'langAttResp', 'langAttRT']
seg = ['fillerCarrier', 'block01', 'block02', 'block03', 'block04', 'block05', 'block06', 'block07', 'block08',
       'block09', 'block10', 'block11', 'block12', 'block13', 'block14', 'block15', 'block16', 'block17', 'block18',
       'block19', 'block20', 'block21', 'block22', 'block23', 'block24', 'block25', 'block26', 'block27', 'block28',
       'block29', 'block30', 'block31', 'block32', 'block33', 'block34', 'block35', 'block36', 'block37', 'block38',
       'block39', 'block40', 'block41', 'block42', 'block43', 'block44', 'block45', 'block46', 'block47', 'block48',
       'segResp', 'segRespRT']
lexEspCols = [*lexDuplicates, *lexEsp, *demCols]
lexEngCols = [*lexDuplicates, *lexEng, *demCols]
sylCols = [*syl, *demCols]
blpCols = [*blp, *demCols]
segCols = [*seg, *demCols]
segKeepCols = [*lexDuplicates, *lexEsp, *lexEng, *sylCols, *segCols, *blpCols, *demCols]
listOfLists = [lexEngCols, lexEspCols, sylCols, blpCols, segCols]
strListOfLists = ['lexEngCols', 'lexEspCols', 'sylCols', 'blpCols', 'segCols']

#tempDir = startDir + '/temp_csv' # is there a way force the creation of this directory if it does not exist?

csvList = dataPreparation.collectFiles(parentDir,startDir) # create list of csv files to modify
# change the headers of csv files
# may have to change relative file path of json map file if you change folder structure
dataPreparation.reMapPandasHeaders('Dissertation_Stats/replacement_map.json',csvList,startDir,tempDir)

# get previously modified csv file as list
csvModList = dataPreparation.collectFiles(parentDir,tempDir)
# Eliminates all unnecessary columns written by PsychoPy
#print(csvModList)
dataPreparation.delPsyPyCols(csvModList,segKeepCols,tempDir, outDir)

# get previously modified csv file as list
csvTaskList = dataPreparation.collectFiles(parentDir,outDir)
#print(csvTaskList)
# Splits file into subsets for analysis and pastes them into temporary directory of stats
i = 0

csvProcList = dataPreparation.collectFiles(parentDir, outDir)
# print(csvProcList,len(csvProcList))
import pandas as pd
for file in csvProcList[0:1]:
       readDir = outDir + '/' + file
       df = pd.read_csv(readDir, index_col=0)

df.info()
# Out:
# /Users/drakeasberry/github/Dissertation
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 873 entries, 0 to 872
# Data columns (total 97 columns):
# word               156 non-null object
# translation        93 non-null object
# corrAnsEspV        93 non-null float64
# fillerCarrier      528 non-null object
# block01            528 non-null object
# block02            528 non-null object
# block03            528 non-null object
# block04            528 non-null object
# block05            528 non-null object
# block06            528 non-null object
# block07            528 non-null object
# block08            528 non-null object
# block09            528 non-null object
# block10            528 non-null object
# block11            528 non-null object
# block12            528 non-null object
# block13            528 non-null object
# block14            528 non-null object
# block15            528 non-null object
# block16            528 non-null object
# block17            528 non-null object
# block18            528 non-null object
# block19            528 non-null object
# block20            528 non-null object
# block21            528 non-null object
# block22            528 non-null object
# block23            528 non-null object
# block24            528 non-null object
# block25            528 non-null object
# block26            528 non-null object
# block27            528 non-null object
# block28            528 non-null object
# block29            528 non-null object
# block30            528 non-null object
# block31            528 non-null object
# block32            528 non-null object
# block33            528 non-null object
# block34            528 non-null object
# block35            528 non-null object
# block36            528 non-null object
# block37            528 non-null object
# block38            528 non-null object
# block39            528 non-null object
# block40            528 non-null object
# block41            528 non-null object
# block42            528 non-null object
# block43            528 non-null object
# block44            528 non-null object
# block45            528 non-null object
# block46            528 non-null object
# block47            528 non-null object
# block48            528 non-null object
# syllabification    58 non-null object
# corrSyl            58 non-null object
# corrAns            58 non-null float64
# leftKey            58 non-null object
# rightKey           58 non-null object
# condition          58 non-null object
# corrAnsEngV        63 non-null float64
# questionNum        43 non-null object
# color              43 non-null object
# sectionEng         43 non-null object
# questionTextEng    43 non-null object
# languageEng        43 non-null object
# lexRespEsp         93 non-null float64
# lexRespEspCorr     93 non-null float64
# lexRespEspRT       93 non-null float64
# segResp            480 non-null object
# segRespRT          47 non-null float64
# sylResp            48 non-null float64
# sylRespCorr        48 non-null float64
# sylRespRT          48 non-null float64
# lexRespEng         63 non-null float64
# lexRespEngCorr     63 non-null float64
# lexRespEngRT       63 non-null float64
# langHistResp1      2 non-null float64
# langHistRT1        2 non-null float64
# langHistResp2      2 non-null float64
# langHistRT2        2 non-null float64
# langHistResp3      8 non-null float64
# langHistRT3        8 non-null float64
# langUseResp        15 non-null float64
# langUseRT          15 non-null float64
# langProfResp       8 non-null float64
# langProfRT         8 non-null float64
# langAttResp        8 non-null float64
# langAttRT          8 non-null float64
# partNum            873 non-null object
# session            873 non-null object
# age                873 non-null int64
# gender             873 non-null object
# birthCountry       873 non-null object
# placeResidence     873 non-null object
# education          873 non-null object
# preferLanguage     873 non-null object
# date               873 non-null object
# expName            873 non-null object
# dtypes: float64(25), int64(1), object(71)
# memory usage: 668.4+ KB
